# %%
import re
from pathlib import Path
from typing import Any

import pandas as pd
import pdfplumber

# %%
pdf_path = Path("../data/soat-traffic-2025.pdf")

# %%
records: list[dict[str, Any]] = []
chapter, article, specialty, section, subsection = None, None, None, None, None

with pdfplumber.open(pdf_path) as pdf:
    for page_num, page in enumerate(pdf.pages[2:62], start=3):
      text = page.extract_text().split("\n")

      for line in text:
        stripped_line = line.strip()

        # Checking the chapter
        chapter_match = re.match(
          r"CAP[IÍ]TULO\s+([IVXLC]+)", stripped_line, re.IGNORECASE
        )
        if chapter_match:
            chapter = f"Capítulo {chapter_match.group(1)}"

        # Checking the article
        article_match = re.match(r"ART[IÍ]CULO\s+(\d+)", stripped_line, re.IGNORECASE)
        if article_match:
            article = f"Artículo {article_match.group(1)}"

            # Looking for the specialty in the same line
            specialty_match = re.search(r"especialidad\s+de\s+(.+?),", stripped_line, re.IGNORECASE)
            if specialty_match:
                specialty = specialty_match.group(1).strip()
            continue

        # Checking the section (fully uppercase, without digits)
        section_match = re.match(r"^(\d+)\.?\s+([A-ZÁÉÍÓÚÜÑ\s]+)\.?$", stripped_line)
        if section_match:
            # Comprobar si la parte numérica tiene punto, si no es así, agregarlo
            # Aplicar capitalize method solo a la parte de texto
            section = f"{section_match.group(1)}. {section_match.group(2).strip().capitalize()}"
            continue

        # Checking the subsection (uppercase, usually longer and may include accents)
        if stripped_line.isupper() and len(stripped_line.split()) > 3 and not stripped_line.startswith("CÓDIGO"):
            subsection = stripped_line.strip().capitalize()
            continue

        # Procedure table row (code, description, and group)
        procedure_match = re.match(r"^(\d{4,5})\s+(.*?)\s+(\d+)$", stripped_line)
        if procedure_match:
            code, description, group = procedure_match.groups()

            records.append({
                "chapter": chapter,
                "article": article,
                "specialty": specialty,
                "section": section,
                "subsection": subsection,
                "code": int(code),
                "description": description.strip(),
                "group": int(group),
                "page": page_num
            })

df = pd.DataFrame(records)

# %%
len(df)
# Out:
# 1771

# %%
df.head(50)
# Out:
#          chapter     article          specialty                    section  \
# 0   Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 1   Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 2   Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 3   Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 4   Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 5   Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 6   Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 7   Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 8   Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 9   Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 10  Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 11  Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 12  Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 13  Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 14  Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 15  Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 16  Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 17  Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 18  Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 19  Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 20  Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 21  Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 22  Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 23  Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 24  Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 25  Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 26  Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 27  Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 28  Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 29  Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 30  Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 31  Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 32  Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 33  Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 34  Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 35  Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 36  Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 37  Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 38  Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 39  Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 40  Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 41  Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 42  Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 43  Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 44  Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 45  Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 46  Capítulo III  Artículo 3  neurocirugía (01)  1. Órganos intracraneales
# 47  Capítulo III  Artículo 3  neurocirugía (01)            2. Derivaciones
# 48  Capítulo III  Artículo 3  neurocirugía (01)            2. Derivaciones
# 49  Capítulo III  Artículo 3  neurocirugía (01)            2. Derivaciones
#
#                                            subsection  code  \
# 0   Craneotomías para tratamiento quirúrgico de le...  1101
# 1   Craneotomías para tratamiento quirúrgico de le...  1102
# 4      Craneotomía para ruptura de senos de duramadre     20     3
# 5   Trepanación para monitoreo de presión intracra...     12     3
# 6     Craneotomía para drenaje hematoma intracerebral     13     3
# 7   Tratamiento de malformaciones arterio venosas ...     21     3
# 8   Tratamiento de malformaciones arterio venosas ...     23     3
# 9   Tratamiento de malformaciones arterio venosas ...     22     3
# 10  Apertura de seno cavernoso por fístula o aneur...     23     3
# 11  Revascularización supratentorial e infratentorial     22     3
# 12                  Endarterectomía de vaso de cuello     21     3
# 13  Embolización para cateterismo de arterias intr...     21     3
# 14                          Angioplastia intraluminar     21     3
# 15  Craneotomía para extirpación adenomas hipofisi...     22     3
# 16  Craneotomía para extirpación adenomas hipofisi...     22     3
# 17     Craneotomía para resección de Cráneofaringioma     23     3
# 18                     coloide del tercer ventrículo)     22     3
# 19                     Craneotomía para pinealectomía     23     3
# 20  Craneotomía para resección de tumores de fosa ...     20     3
# 21  Craneotomía para resección de tumores de fosa ...     20     3
# 22  Craneotomía para resección de tumores de fosa ...     21     3
# 23  Craneotomía para tumores del ángulo ponto cere...     22     3
# 24  Tratamiento por vía anterior para tumores de c...     23     3
# 25         Craneotomía para tumores de hoz de cerebro     20     3
# 26         Craneotomía para tumores de cuerpo calloso     20     4
# 27                                         Leucotomía     12     4
# 28                                         Lobectomía     20     4
# 29             Lobotomía (psicocirugía estereotáxica)     12     4
# 30                                    Hemisferectomía     22     4
# 31  Extirpación de lesión y/o tejido de las mening...     20     4
# 32                            Reparación encéfalocele     20     4
# 33                     Reparación meningocele craneal     20     4
# 34  Tratamiento de platibasia (Síndrome de Arnold ...     22     4
# 35                Corrección de enfermedad de Crouzón     23     4
# 36       Injertos intracraneanos (médula suprarrenal)     22     4
# 37  Punción estereotáxica de quistes, abcesos y he...     20     4
# 38  Implantación estereotáxica de electrodos y mat...     22     4
# 39        Biopsia esterotáxica de lesiones cerebrales     20     4
# 40                    Corrección hundimiento craneano     12     4
# 41                                Craniectomía lineal     12     4
# 42  Craneoplastia para corrección de defecto por r...     20     4
# 43                             Esquirlectomía craneal     12     4
# 44                         Craneoplastia con acrílico     13     4
# 45                    Craneoplastia con remplazo óseo     20     4
# 46  Tratamiento para descompresión y corrección ór...     21     4
# 47                       Derivación ventrículo atrial     13     4
# 48                   Derivación ventrículo peritoneal     13     4
# 49                      Derivación ventrículo pleural     13     4

# %%
df["group"].unique(), len(df["group"].unique())
# Out:
# (array([ 9, 20,  8, 12, 13, 21, 23, 22, 10,  4,  5,  3,  6,  7, 11,  2]), 16)

# %%
df[df["code"] == 18401]
# Out:
#            chapter      article         specialty  \
# 1714  Capítulo III  Artículo 20  Cirugía Plástica
#
#                           section                               subsection  \
# 1714  4. Páncreas y vías biliares  3 esófago, estómago e intestino delgado
#
#        code                                        description  group  page
# 1714  18401  E R C P Endoscopia para colangiopancreatografí...     10    60

# %%
df["specialty"].unique(), len(df["specialty"].unique())
# Out:
# (array(['neurocirugía (01)', 'Cirugía Plástica'], dtype=object), 2)

# %%
df["section"].unique(), len(df["section"].unique())
# Out:
# (array(['1. Órganos intracraneales', '2. Derivaciones',
#         '3. Raquis y médula espinal', '4. Pares craneanos',
#         '5. Nervios y ganglios simpáticos', '6. Plejos',
#         '1. Aparato lagrimal', '2. Párpados', '3. Conjuntiva', '4. Órbita',
#         '5. Globo y músculos oculares', '6. Córnea y esclerótica',
#         '7. Iris y cuerpo ciliar', '8. Cámara anterior y retina',
#         '9. Cristalino y cuerpo vítreo', '1. Oído externo',
#         '2. Oído medio y mastoides', '3. Oído interno',
#         '4. Nariz y senos paranasales', '5. Laringe y tráquea',
#         '1. Glándulas tiroides y paratiroides',
#         '1. Vasos sanguíneos periféricos', '2. Sistema linfático',
#         '4. Vasos sanguíneos intraabdominales', '5. Vasos intratorácicos',
#         '6. Corazón y pericardio',
#         '7. Otros procedimientos dirigidos al corazón', '2. Bronquios',
#         '3. Pulmón', '4. Esófago', '1. Pared abdominal y peritoneo',
#         '2. Hígado y vías biliares', '3. Páncreas',
#         '4. Glándulas suprarrenales', '5. B a z o', '6. Estómago',
#         '7. Intestino', '8. Médula ósea', '1. Recto', '2. Ano', '1. Riñon',
#         '2. Ureter', '3. Vejiga', '4. Uretra',
#         '5. Próstata y vesículas seminales',
#         '7. Epididimo y conducto deferente', '8. Pene', '1. Mama',
#         '1. Ovario', '2. Trompa de falopio', '3. Ligamento ancho',
#         '4. Útero', '5. Vagina', '1. Útero', '1. Hombro y brazo',
#         '2. Antebrazo y codo', '3. Pelvis y cadera', '4. Muslo y rodilla',
#         '6. Columna vertebral y tórax', '7. Articulaciones', '1. Huesos',
#         '2. Músculos y tendones', '4. Nervio s', '5. Piel',
#         '6. Reimplantes y transposiciones', '1. Area general',
#         '2. Área especial', '1. Glándulas y conductos salivales',
#         '3. Maxilares y articulación temporomandibular',
#         '4. Huesos faciales', '1. Tejido nervioso',
#         '2. Órganos de los sentidos', '3. Boca y cuello',
#         '4. Órganos intratorácicos', '5. Órganos intraabdominales',
#         '6. Glándulas suprarrenales y aparato genitourinario',
#         '7. Vasos sanguíneos y linfáticos', '8. Aparato locomotor',
#         '1. Aparato respiratorio y mediastino', '2. Articulaciones',
#         '4. Páncreas y vías biliares', '5. Colon', '6. Abdomen',
#         '8. Uretra y próstata', '9. Aparato genital femenino'],
#        dtype=object),
#  85)

# %% [markdown]
# #### Servicios profesionales del cirujano o ginecoobstetra

# %%
records: list[dict[str, Any]] = []

with pdfplumber.open(pdf_path) as pdf:
  page = pdf.pages[96:97][0].extract_text()
  match = re.search(r"1.\sServicios profesionales del cirujano o ginecoobstetra:", page)
  result = page[match.start():].split("\n") if match else []
  rows = result[1:-1]

  def get_record(row: str) -> dict[str, Any]:
    """Extracts a record from a row of text."""
    row_match = re.match(
      r"^(\d{5})\s+(Grupo\s+(?:\d+|especial\s+\d+))\s+([\d,]+)\s+([\d\.]+)$",
      row,
      re.IGNORECASE,
    )
    if not row_match:
      return {}
    return {
      "code": int(row_match.group(1)),
      "group": int(row_match.group(2).split()[-1]),
      "special": str(row_match.group(2)).find("especial") != -1,
      "Fee (S.M.L.D.V)": float(row_match.group(3).replace(",", ".")),
      "Fee (COP)": int(row_match.group(4).replace(".", "")),
    }

  records = list(map(get_record, rows))

pd.DataFrame(records)
# Out:
#      code  group  special  Fee (S.M.L.D.V)  Fee (COP)
# 0   39000      2    False             2.93     139000
# 1   39001      3    False             3.57     169400
# 2   39002      4    False             4.31     204500
# 3   39003      5    False             5.86     278100
# 4   39004      6    False             7.68     364400
# 5   39005      7    False             9.00     427100
# 6   39006      8    False            10.44     495400
# 7   39007      9    False            12.76     605500
# 8   39008     10    False            15.71     745400
# 9   39009     11    False            17.62     836100
# 10  39010     12    False            19.63     931400
# 11  39011     13    False            21.48    1019200
# 12  39012     20     True            25.43    1206700
# 13  39013     21     True            33.10    1570600
# 14  39014     22     True            38.67    1834900
# 15  39015     23     True            60.73    2881600

# %% [markdown]
# ### Servicios profesionales del anestesiólogo

# %%
records: list[dict[str, Any]] = []

with pdfplumber.open(pdf_path) as pdf:
  page = pdf.pages[97:98][0].extract_text().split("\n")
  rows = page[2:18]

  def get_record(row: str) -> dict[str, Any]:
    """Extracts a record from a row of text."""
    row_match = re.match(
      r"^(\d{5})\s+(Grupo\s+(?:\d+|especial\s+\d+))\s+([\d,]+)\s+([\d\.]+)$",
      row,
      re.IGNORECASE,
    )
    if not row_match:
      return {}
    return {
      "code": int(row_match.group(1)),
      "group": int(row_match.group(2).split()[-1]),
      "special": str(row_match.group(2)).find("especial") != -1,
      "Fee (S.M.L.D.V)": float(row_match.group(3).replace(",", ".")),
      "Fee (COP)": int(row_match.group(4).replace(".", "")),
    }

  records = list(map(get_record, rows))

pd.DataFrame(records)
# Out:
#      code  group  special  Fee (S.M.L.D.V)  Fee (COP)
# 0   39100      2    False             2.09      99200
# 1   39101      3    False             2.53     120000
# 2   39102      4    False             3.10     147100
# 3   39103      5    False             3.83     181700
# 4   39104      6    False             4.56     216400
# 5   39105      7    False             5.30     251500
# 6   39106      8    False             6.17     292800
# 7   39107      9    False             7.30     346400
# 8   39108     10    False             9.02     428000
# 9   39109     11    False            10.08     478300
# 10  39110     12    False            11.44     542800
# 11  39111     13    False            12.72     603600
# 12  39112     20     True            14.85     704600
# 13  39113     21     True            20.12     954700
# 14  39114     22     True            26.82    1272600
# 15  39115     23     True            37.95    1800700
